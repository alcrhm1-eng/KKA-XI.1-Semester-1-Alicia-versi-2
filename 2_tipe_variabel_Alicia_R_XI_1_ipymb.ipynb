# %% [markdown]
# <a href="https://colab.research.google.com/github/alcrhm1-eng/KKA-XI.1-Semester-1-Alicia-versi-2/blob/main/2_tipe_variabel_Alicia_R_XI_1_ipymb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Alicia Rahma
#
# Kelas:XI.1
#
# No. Absen: 04
#
# #Konsep Dasar

# %%
email_user_1 = "alcrhm1@gmail.com"

print(email_user_1)
# Out:
# alcrhm1@gmail.com

# %%
sabun_lifebouy = 15000

print(sabun_lifebouy)
# Out:
# 15000

# %%
print(sabun_lifebouy*5)
# Out:
# 75000

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#Penulisan Variabel hanya boleh menggunakan huruf, angka dan underscore
#Tidak boleh menggunakan spasi
nama siswa = "Alic"

print(nama siswa)
# Out:
#   File "/tmp/ipython-input-910164564.py", line 3
#     nama siswa = "Alic"
#          ^
# SyntaxError: invalid syntax

# %%
#Tidak boleh diawali dengan angka

1_nama_siswa = "alic"
print(1_nama_siswa)
# Out:
#   File "/tmp/ipython-input-3374561328.py", line 3
#     1_nama_siswa = "alic"
#      ^
# SyntaxError: invalid decimal literal

# %%
#penulisan variabel itu case sensitive/sensitif capslock
nama_siswa_1 = "alic"

print(Nama_siswa_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4279924924.py in <cell line: 0>()
#       2 nama_siswa_1 = "alic"
#       3
# ----> 4 print(Nama_siswa_1)
#
# NameError: name 'Nama_siswa_1' is not defined

# %%
#dilarang menggunakan kata kunci di bahasa python
prin="alic"

print(prin)
# Out:
# alic

# %%
end="alic"

print(end)
# Out:
# alic

# %%
#Deskriptif
_ = "Alicia"

print(_)
# Out:
# Alicia

# %%
#Tidak boleh pakai kata kunci python
#Kalau error, harus disconnect dulu
#Print = "Alicia"

#Print(print)

# %% [markdown]
# #Assignment

# %% [markdown]
# ##Single Assignment

# %%
nama_siswa_2 = "Dhapne"
nama_siswa_3 = "Farel"
print(nama_siswa_2)
print(nama_siswa_3)
# Out:
# Dhapne
# Farel

# %% [markdown]
# ##Multiple Assignment

# %%
nama_siswa_4, nama_siswa_5, = "Sada", "Shello"

print(nama_siswa_4)
print(nama_siswa_5)
# Out:
# Sada
# Shello

# %% [markdown]
# ##Assign ke Banyak Variabel Sekaligus

# %%
nilai_afa = nilai_favian = 100

print(nilai_afa)
print(nilai_favian)
# Out:
# 100
# 100

# %% [markdown]
# ##Perubahan Nilai Variabel

# %%
nilai_afa = 95
print(nilai_afa)
# Out:
# 95

# %% [markdown]
# #Aritmatika

# %%
print("5000*3")
# Out:
# 5000*3

# %%
#Operand tanpa disimpan dalam variabel
print(5000*3)
# Out:
# 15000

# %%
#simpan operand ke dalam variabel
harga_kojek = 6000
banya_porsi = 3

print(harga_kojek*banya_porsi)
# Out:
# 18000

# %%
#simpan hasil operasi ke dalam variabel
harga_total_kojek = 3000*3

print(harga_total_kojek)
# Out:
# 9000

# %%
#simpan nilai operand dan hasil operasi ke dalam variabel
harga_cilok = 10000
jumlah_porsi_cilok = 5
harga_total_cilok = harga_cilok *jumlah_porsi_cilok

print(harga_total_cilok)
# Out:
# 50000

# %%
uang_yang_diterima =100000
uang_kembalian = uang_yang_diterima-harga_total_cilok

print(uang_kembalian)
# Out:
# 50000

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print(banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3
total_jumlah_botol = 24*3

print(total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #Tipe Variabel

# %%
usia = 65

type(usia)
# Out:
# int

# %%
berat_telur = 2.5

type(berat_telur)
# Out:
# float

# %%
nama = "Alicia"

type(nama)
# Out:
# str

# %%
remidi = False

type(remidi)
# Out:
# bool

# %%
remidi = True

type(remidi)
# Out:
# bool

# %%
koordinat_bintang = -1.5

type(koordinat_bintang)
# Out:
# float

# %%
koordinat_titik = -8

type(koordinat_titik)
# Out:
# int

# %% [markdown]
# #Input

# %%
panjang = 10
lebar = 5
luas = panjang*lebar

print(luas)
# Out:
# 50

# %%
input()
# Out:
# 10
# '10'

# %%
panjang =input()
# Out:
# 10

# %%
print(panjang)
# Out:
# 10

# %%
lebar = input()
# Out:
# 5

# %%
print(lebar)
# Out:
# 5

# %%
luas = panjang*lebar

print(luas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-508063834.py in <cell line: 0>()
# ----> 1 luas = panjang*lebar
#       2
#       3 print(luas)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
type(panjang)
# Out:
# str

# %%
type(lebar)
# Out:
# str

# %%
panjang = int(panjang)

# %%
lebar = int(lebar)

# %%
type(panjang)
# Out:
# int

# %%
panjang_1 = int(input("Masukkan panjang persegi: "))
# Out:
# Masukkan panjang persegi: 10

# %%
panjang_2 = int(input("Masukkan panjang persegi: "))
lebar_2 = int(input("Masukkan lebar persegi: "))

luas_2 = panjang_2*lebar_2

print(f"Luas persegi panjang adalah {luas_2} cm^2")
# Out:
# Masukkan panjang persegi: 10
# Masukkan lebar persegi: 5
# Luas persegi panjang adalah 50 cm^2

# %%
panjang_3 = int(input("Masukkan panjang balok: "))
lebar_3 = int(input("Masukkan lebar balok: "))
tinggi_3 = int(input("Masukkan tinggi balok: "))

volume_3 = panjang_3*lebar_3*tinggi_3

print(f"Volume balok adalah {volume_3} cm³")
# Out:
# Masukkan panjang balok: 10
# Masukkan lebar balok: 5
# Masukkan tinggi balok: 4
# Volume balok adalah 200 cm³

# %% [markdown]
# #Konversi Tipe Data

# %%
a = 3
print(a)
type(a)
# Out:
# 3
# int

# %%
a = float(a)
print(a)
type(a)
# Out:
# 3.0
# float

# %%
a = str(a)
print(a)
type(a)
# Out:
# 3.0
# str

# %%
a = bool(a)
print(a)
type(a)
# Out:
# True
# bool

# %%
b = "cicak"
print(b)

b = bool(b)
print(b)
# Out:
# cicak
# True

# %%
c = ""
print(c)

c = bool(c)
print(c)
# Out:
# False

# %%
d = False
print(d)
type(d)
# Out:
# False
# bool

# %%
e = "False"
print(e)
type(e)
# Out:
# False
# str
