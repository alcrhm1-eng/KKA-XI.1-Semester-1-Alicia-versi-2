# %% [markdown]
# <a href="https://colab.research.google.com/github/alcrhm1-eng/KKA-XI.1-Semester-1-Alicia-versi-2/blob/main/Fungsi_print_Alicia_XI_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print ("Halo dunia")
# Out:
# Halo dunia

# %%
print ("selamat datang di python")
# Out:
# selamat datang di python

# %%
print ("Alicia Rahma")
# Out:
# Alicia Rahma

# %% [markdown]
# #Variabel

# %%
BB = 50
print (BB)
# Out:
# 50

# %%
UMUR = 16
print (UMUR)
# Out:
# 16

# %%
nama = "Alicia Rahma"

# %% [markdown]
# #Menampilkan Teks Bebas dan Variabel

# %%
print (f"umur saya {UMUR} tahun")
# Out:
# umur saya 16 tahun

# %%
print ("Halo " + nama)
# Out:
# Halo Alicia Rahma

# %% [markdown]
# #Menampilkan Variabel dan Teks Bebas

# %%
harga_telur = 26000

print("Harga telur per 1 kg adalah " + str(harga_telur))
# Out:
# Harga telur per 1 kg adalah 26000

# %%
harga_telur = 26000

print ("harga telur per 1 kg adalah", harga_telur)
# Out:
# harga telur per 1 kg adalah 26000

# %%
nama_pembeli = "Rafael"

print("Nama pembeli telur adalah " + nama_pembeli)
# Out:
# Nama pembeli telur adalah Rafael

# %% [markdown]
# Latihan Soal
#
# 1. Tampilkan teks bebas: hari ini saya bahagia belajar bahasa python
# 2. Tampilkan nilai variabel: mata_pelajaran_favorit = Kode dan Kecerdasan Buatan
# 3. Tampilkan nilai variabel: nilai_kka = 100
# 4. Tampilkan teks bebas dan nilai variabel dengan tiga metode (f string,"+",","):"Nilai KKA saya adalah {nilai_kka} loh!"

# %%
print ("hari ini saya bahagia belajar bahasa python")
# Out:
# hari ini saya bahagia belajar bahasa python

# %%
mata_pelajaran_favorit = "Kode dan Kecerdasan Buatan"
print (mata_pelajaran_favorit)
# Out:
# Kode dan Kecerdasan Buatan

# %%
nilai_kka = 100
print(nilai_kka)
# Out:
# 100

# %%
print(f"Nilai KKA saya adalah {nilai_kka} loh!")
# Out:
# Nilai KKA saya adalah 100 loh!

# %%
print("Nilai KKA saya adalah " + str(nilai_kka) + " loh! ")
# Out:
# Nilai KKA saya adalah 100 loh!

# %%
print("Nilai KKA saya adalah" , nilai_kka , " loh! ")

# %% [markdown]
# #Escape Character

# %%
print ("Nama: Alicia Rahma")
print ("Kelas: XI.1")
print ("Nomor absen: 04")
# Out:
# Nama: Alicia Rahma
# Kelas: XI.1
# Nomor absen: 04

# %%
print ("Nama: Alicia Rahma\nKelas: XI.1\nNomor absen: 04")
# Out:
# Nama: Alicia Rahma
# Kelas: XI.1
# Nomor absen: 04

# %%
print ("""Nama: Alicia Rahma
Kelas: XI.1
Nomor absen: 04""")
# Out:
# Nama: Alicia Rahma
# Kelas: XI.1
# Nomor absen: 04

# %%
print ("Nama\t\t: Alicia Rahma\nKelas\t\t: XI.1\nNomor absen\t: 04")
# Out:
# Nama		: Alicia Rahma
# Kelas		: XI.1
# Nomor absen	: 04

# %%
print('Ja\'far Shodiq')
# Out:
# Ja'far Shodiq

# %%
print("Ja'far Shodiq")
# Out:
# Ja'far Shodiq

# %%
print("Bu Shinta berkata, \"Semua harus menyimak pelajaran.\"")
# Out:
# Bu Shinta berkata, "Semua harus menyimak pelajaran."

# %%
print('Bu Shinta berkata "Semua harus menyimak pelajaran."')
# Out:
# Bu Shinta berkata "Semua harus menyimak pelajaran."

# %%
print("Lokasi file video karnaval ada di D:\\Karnaval 2025 \\mp4")
# Out:
# Lokasi file video karnaval ada di D:\Karnaval 2025 \mp4

# %% [markdown]
# #Parameter Fungsi Print

# %%
Tahun = 2008
Bulan = "May"
Tanggal = 31

print(Tanggal, end=" ")
print(Bulan, end=" ")
print(Tahun)
# Out:
# 31 May 2008

# %%
Tahun = 2008
Bulan = "May"
Tanggal = 31

print(Tanggal, Bulan, Tahun, sep="/")
# Out:
# 31/May/2008

# %%
Tahun = 2008
Bulan = "May"
Tanggal = 31

print(Tanggal, Bulan, Tahun, sep="-")
# Out:
# 31-May-2008

# %%
Nama_depan = "Alicia"
Nama_belakang = "Rahma"

print(Nama_depan, Nama_belakang)
# Out:
# Alicia Rahma

# %%
Nama_depan = "Alicia"
Nama_belakang = "Rahma"

print(Nama_depan, end=" ")
print(Nama_belakang)
# Out:
# Alicia Rahma

# %%
print('Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\\Jadwal Pelajaran\\Kelas XI Semester 1", end')
print("\nJadwal Pelajaran Minggguan")
print("====================================================")
print("Jam\tSenin\t\tSelasa\t\tRabu")
print("Jam 1\tMatematika\tBahasa\t\tInformatika")
print("Jam 2\tBahasa Ing\tSejarah\t\tMa'rifatullah")
print("Jam 3\tInformatika\tOlahraga\tBiologi")
# Out:
# Bu Shinta berkata, "berikut adalah judul pelajaran hari senin selasa rabu silakan disimpan di laptop masing-masing di folder local disk D:\Jadwal Pelajaran\Kelas XI Semester 1", end
#
# Jadwal Pelajaran Minggguan
# ====================================================
# Jam	Senin		Selasa		Rabu
# Jam 1	Matematika	Bahasa		Informatika
# Jam 2	Bahasa Ing	Sejarah		Ma'rifatullah
# Jam 3	Informatika	Olahraga	Biologi
